# %% [markdown]
# EDA EXPLORATORY DATA ANALYSIS ON EMPLOYEES DATASET

# %% [markdown]
# 1.IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2.DATA SET LOADING

# %%
df=pd.read_csv("myproject.csv.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# 3.UNDERSTANDING THE DATASET

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %% [markdown]
# 4.HANDLING THE MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# Data story : Columns College has 84 and Salary has 11 Null Values

# %% [markdown]
# Salary Distribution of Different Players

# %%
plt.scatter(range(len(df['Salary'])),df['Salary'])
plt.xlabel('Index')
plt.ylabel('Salary')
plt.title('Scatter plot of Salaries')
plt.show()

# %% [markdown]
# #Filling the null values in salary column with 0.

# %%
df['Salary'].fillna(0,inplace=True)

# %% [markdown]
# #filling the null values in 'College' column with'Unknown'

# %%
df['College'].fillna('Unknown',inplace=True)

# %% [markdown]
# 5.Handling Duplicate Values

# %%
duplicate=df[df.duplicated()]
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %% [markdown]
# Data Story : No duplicate Rows in this dataset.

# %% [markdown]
# 6.Filling Column 'Height' with Random values Between 150-180.

# %%
df['Height']=np.random.uniform(150,180,len(df))
df['Height']
# Out:
# 0      150.326768
# 1      172.459409
# 2      161.217554
# 3      150.929471
# 4      164.246389
#           ...
# 453    162.026252
# 454    163.489698
# 455    152.250816
# 456    170.975488
# 457    169.971338
# Name: Height, Length: 458, dtype: float64

# %% [markdown]
# Table of Contents

# %% [markdown]
# 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
df['Team'].nunique()
# Out:
# 30

# %%
Team_counts=df['Team'].value_counts()
print(Team_counts)
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
df['Name'].nunique()
# Out:
# 458

# %%
percentage=Team_counts*(100/458)
print(percentage)
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
x=percentage.index
y=percentage.values
plt.bar(x,y)
plt.xticks(rotation='vertical')
plt.xlabel('Team')
plt.ylabel('percentage')
plt.title('percentage splitting of members in each team with respect to the total employees')
plt.show()

# %% [markdown]
# #Team 'New Orleans Pelicans' have highest number of players.

# %% [markdown]
# 2.Segregate the employees w.r.t different positions.

# %%
df['Position'].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
Position=df['Position'].value_counts()
print(Position)
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
grouped= df.groupby('Position')
grouped_to_string=df.groupby('Position')['Name'].apply(list).reset_index()
print(grouped_to_string)
# Out:
#   Position                                               Name
# 0        C  [Kelly Olynyk, Jared Sullinger, Tyler Zeller, ...
# 1       PF  [Jonas Jerebko, Amir Johnson, Jordan Mickey, C...
# 2       PG  [Avery Bradley, Terry Rozier, Marcus Smart, Is...
# 3       SF  [Jae Crowder, Thanasis Antetokounmpo, Carmelo ...
# 4       SG  [John Holland, R.J. Hunter, Evan Turner, James...

# %%
plt.bar(position.index,position.values,color='b',width=0.5)
plt.xlabel('Position')
plt.ylabel('Number of employees')
plt.show()

# %% [markdown]
# #Position 'SG' has most number of players

# %% [markdown]
# 3.Find from which age group most of the employees belong to ?

# %%
data=df['Age'].value_counts()
data
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.hist(data.index,bins=[19,29,39,49],edgecolor='black')
plt.xlabel('Age')
plt.title('Histogram Showing Age and Frequency of Employees')
plt.show()

# %% [markdown]
# #Most number of employees are in between 19-29 and 29-39 age group.A few are in the age between 39 and 49

# %% [markdown]
# 4.Find out under which team and position,spending in terms of salary is high.

# %%
group_data=df.groupby(['Team','Position'])['Salary'].sum()
group_data
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: float64

# %%
sorted_data=group_data.sort_values(ascending=False)
print(sorted_data.head())
# Out:
# Team                Position
# Los Angeles Lakers  SF          31866445.0
# Miami Heat          PF          31538671.0
# Houston Rockets     SG          28122883.0
# Phoenix Suns        PG          28002998.0
# Denver Nuggets      SF          27982771.0
# Name: Salary, dtype: float64

# %% [markdown]
# #Team Los Angeles Lakers with Position SF,spends the highest for salary

# %%
plt.bar(df['Team'],df['Salary'],color='r',edgecolor='brown')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# #Los Angles Lakers spends more on Salary

# %% [markdown]
# 5.Find if there is any correlation between age and salary.Represent it visually.

# %%
correlation=df['Age'].corr(df['Salary'])
print(correlation)
# Out:
# 0.2140094122657097

# %%
plt.scatter(df['Age'],df['Salary'])
plt.title('Age vs Salary Scatter Plot')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# #There is a weak positive correlation between Age and Salary.As age increases ,salary tends to increases slightly,but the relationship is not very strong

# %% [markdown]
# Exploring some possible correlations.

# %% [markdown]
# Employees position and their salary relationship

# %%
position_salary=df.groupby('Position')['Salary'].sum()
position_salary
# Out:
# Position
# C     466377332.0
# PF    442560850.0
# PG    446848971.0
# SF    408020976.0
# SG    396976258.0
# Name: Salary, dtype: float64

# %%
sns.boxplot(x='Position',y='Salary',data=df,color='m')
plt.title('Salary distribution by Position',color='r',size=25)
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# #Employees in position 'C' tend to get higher salaries than other positions.

# %% [markdown]
# Relationship between a player's weight and their position.

# %%
sns.violinplot(x='Position',y='Weight',data=df)
plt.title("Comparison of Employees' Weight Across Positions")
plt.show()

# %% [markdown]
# The violoin plot shows that there is a relation betweenweight and position they occupy.Employees with more weight tend to occupy position 'C' while employees with less weight tend to occupy position 'PG'

# %% [markdown]
# Conclusion

# %% [markdown]
# These are the Following conclusion

# %% [markdown]
# 1.Team 'New Orleans Pelicans' have highest number of players.

# %% [markdown]
# 2.Position 'SG' has most number of players

# %% [markdown]
# 3.Most number of employees are in between 19-29 and 29-39 age group.A few are in the age between 39 and 49

# %% [markdown]
# 4.Team Los Angeles Lakers with Position SF,spends the highest for salary

# %% [markdown]
# 5.There is a weak positive correlation between Age and Salary.As age increases ,salary tends to increases slightly,but the relationship is not very strong
